# %%
# !pip install xlrd

# %%
#Import the Pandas Library into your development environment, Pandas is a data analytics library developed in Python.

import pandas as pd #any objects dependant on libraries need to have the library referenced, so we use the shorter 'pd' instead of pondas

# %%
# Read data from CSV file

csv_path = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%204/data/TopSellingAlbums.csv'
df = pd.read_csv(csv_path)
df
# Out:
#              AC/DC                    Back in Black  1980  0:42:11  \
# 0       Pink Floyd        The Dark Side of the Moon  1973  0:42:49
# 1  Whitney Houston                    The Bodyguard  1992  0:57:44
# 2        Meat Loaf                  Bat Out of Hell  1977  0:46:33
# 3           Eagles  Their Greatest Hits (1971-1975)  1976  0:43:08
# 4         Bee Gees             Saturday Night Fever  1977  1:15:54
# 5    Fleetwood Mac                          Rumours  1977  0:40:01
#
#                      hard rock  26.1  50  25-Jul-80 Unnamed: 8  9.5
# 0             progressive rock  24.2  45  01-Mar-73        NaN  9.0
# 1               R&B, soul, pop  27.4  44  17-Nov-92          Y  8.5
# 2  hard rock, progressive rock  20.6  43  21-Oct-77        NaN  8.0
# 3   rock, soft rock, folk rock  32.2  42  17-Feb-76        NaN  7.5
# 4                        disco  20.6  40  15-Nov-77          Y  7.0
# 5                    soft rock  27.9  40  04-Feb-77        NaN  6.5

# %%
# Print first five rows of the dataframe, can add a second argument to change the heading row

df.head() # defaults to first 5 rows
# Out:
#             Artist                      Album  Released   Length  \
# 0  Michael Jackson                   Thriller      1982  0:42:19
# 1            AC/DC              Back in Black      1980  0:42:11
# 2       Pink Floyd  The Dark Side of the Moon      1973  0:42:49
# 3  Whitney Houston              The Bodyguard      1992  0:57:44
# 4        Meat Loaf            Bat Out of Hell      1977  0:46:33
#
#                          Genre  Music Recording Sales (millions)  \
# 0               pop, rock, R&B                              46.0
# 1                    hard rock                              26.1
# 2             progressive rock                              24.2
# 3               R&B, soul, pop                              27.4
# 4  hard rock, progressive rock                              20.6
#
#    Claimed Sales (millions) Released.1 Soundtrack  Rating
# 0                        65  30-Nov-82        NaN    10.0
# 1                        50  25-Jul-80        NaN     9.5
# ...

# %%
df.tail() # defaults to last 5 rows
# Out:
#             Artist                            Album  Released   Length  \
# 3  Whitney Houston                    The Bodyguard      1992  0:57:44
# 4        Meat Loaf                  Bat Out of Hell      1977  0:46:33
# 5           Eagles  Their Greatest Hits (1971-1975)      1976  0:43:08
# 6         Bee Gees             Saturday Night Fever      1977  1:15:54
# 7    Fleetwood Mac                          Rumours      1977  0:40:01
#
#                          Genre  Music Recording Sales (millions)  \
# 3               R&B, soul, pop                              27.4
# 4  hard rock, progressive rock                              20.6
# 5   rock, soft rock, folk rock                              32.2
# 6                        disco                              20.6
# 7                    soft rock                              27.9
#
#    Claimed Sales (millions) Released.1 Soundtrack  Rating
# 3                        44  17-Nov-92          Y     8.5
# ...

# %%
df.head(7) # you can enter an argument to display the number of rows
# Out:
#             Artist                            Album  Released   Length  \
# 0  Michael Jackson                         Thriller      1982  0:42:19
# 1            AC/DC                    Back in Black      1980  0:42:11
# 2       Pink Floyd        The Dark Side of the Moon      1973  0:42:49
# 3  Whitney Houston                    The Bodyguard      1992  0:57:44
# 4        Meat Loaf                  Bat Out of Hell      1977  0:46:33
# 5           Eagles  Their Greatest Hits (1971-1975)      1976  0:43:08
# 6         Bee Gees             Saturday Night Fever      1977  1:15:54
#
#                          Genre  Music Recording Sales (millions)  \
# 0               pop, rock, R&B                              46.0
# 1                    hard rock                              26.1
# 2             progressive rock                              24.2
# 3               R&B, soul, pop                              27.4
# 4  hard rock, progressive rock                              20.6
# ...

# %%
# Read data from Excel File and print the first five rows

xlsx_path = 'https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/Chapter%204/Datasets/TopSellingAlbums.xlsx'

df = pd.read_excel(xlsx_path)
df.head()
# Out:
#             Artist                      Album  Released    Length  \
# 0  Michael Jackson                   Thriller      1982  00:42:19
# 1            AC/DC              Back in Black      1980  00:42:11
# 2       Pink Floyd  The Dark Side of the Moon      1973  00:42:49
# 3  Whitney Houston              The Bodyguard      1992  00:57:44
# 4        Meat Loaf            Bat Out of Hell      1977  00:46:33
#
#                          Genre  Music Recording Sales (millions)  \
# 0               pop, rock, R&B                              46.0
# 1                    hard rock                              26.1
# 2             progressive rock                              24.2
# 3               R&B, soul, pop                              27.4
# 4  hard rock, progressive rock                              20.6
#
#    Claimed Sales (millions) Released.1 Soundtrack  Rating
# 0                        65 1982-11-30        NaN    10.0
# 1                        50 1980-07-25        NaN     9.5
# ...

# %%
# Access to the column Length

x = df[['Length']]
x
# Out:
#      Length
# 0  00:42:19
# 1  00:42:11
# 2  00:42:49
# 3  00:57:44
# 4  00:46:33
# 5  00:43:08
# 6  01:15:54
# 7  00:40:01

# %%
# Gives the output of same info but in different order

x = df[['Length', 'Album']]
x
# Out:
#      Length                            Album
# 0  00:42:19                         Thriller
# 1  00:42:11                    Back in Black
# 2  00:42:49        The Dark Side of the Moon
# 3  00:57:44                    The Bodyguard
# 4  00:46:33                  Bat Out of Hell
# 5  00:43:08  Their Greatest Hits (1971-1975)
# 6  01:15:54             Saturday Night Fever
# 7  00:40:01                          Rumours

# %%
y= df[['Album','Length']]
y
# Out:
#                              Album    Length
# 0                         Thriller  00:42:19
# 1                    Back in Black  00:42:11
# 2        The Dark Side of the Moon  00:42:49
# 3                    The Bodyguard  00:57:44
# 4                  Bat Out of Hell  00:46:33
# 5  Their Greatest Hits (1971-1975)  00:43:08
# 6             Saturday Night Fever  01:15:54
# 7                          Rumours  00:40:01

# %%
# Access to multiple columns

y = df[['Artist','Length','Genre']]
y
# Out:
#             Artist    Length                        Genre
# 0  Michael Jackson  00:42:19               pop, rock, R&B
# 1            AC/DC  00:42:11                    hard rock
# 2       Pink Floyd  00:42:49             progressive rock
# 3  Whitney Houston  00:57:44               R&B, soul, pop
# 4        Meat Loaf  00:46:33  hard rock, progressive rock
# 5           Eagles  00:43:08   rock, soft rock, folk rock
# 6         Bee Gees  01:15:54                        disco
# 7    Fleetwood Mac  00:40:01                    soft rock

# %%
# Get the column as a series

x = df['Length']
x
# Out:
# 0    00:42:19
# 1    00:42:11
# 2    00:42:49
# 3    00:57:44
# 4    00:46:33
# 5    00:43:08
# 6    01:15:54
# 7    00:40:01
# Name: Length, dtype: object

# %%
# This will give an error because you can't have a double key at the same time in a series

x = df['Length', 'Album']
x
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Programs\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Length', 'Album')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-67b21369f717> in <module>
# ...

# %%
# Get the column as a dataframe

x = type(df[['Artist']])
x
# Out:
# pandas.core.frame.DataFrame

# %%
x = type(type(df[['Artist']]))
x
# Out:
# type

# %%
# Access the value on the first row and the first column remember it is indexed from 0,0!

df.iloc[0, 0]
# Out:
# 'Michael Jackson'

# %%
# Access the value on the second row and the first column

df.iloc[1,0]
# Out:
# 'AC/DC'

# %%
# Access the value on the first row and the third column

df.iloc[0,2]
# Out:
# 1982

# %%
# Access the value on the second row and the third column
df.iloc[1,2]

# %%
# Access the column using the name, use the loc method for string valued arguments

df.loc[1, 'Artist'] #Use loc instead of iloc while using a string parameter and also you can't use numbers in the column's argument
# Out:
# 'AC/DC'

# %%
# Access the column using the name

df.loc[1, 'Artist']

# %%
# Access the column using the name

df.loc[0, 'Released']
# Out:
# 1982

# %%
# Access the column using the name

df.loc[1, 'Released']

# %%
# Gives Error when we use iloc !!
df.iloc[1, 'Artist'] #don't use iloc for any string arguments

# %%
# Slicing the dataframe

df.iloc[0:2, 0:1]    # iloc doesn't include the row indexed by 2 and coloumn indexed 3
# Out:
#             Artist
# 0  Michael Jackson
# 1            AC/DC

# %%
# Slicing the dataframe using name

df.loc[0:2, 'Artist':'Released'] # loc includes the row indexed by number 2 and includes the rows indexed by strings
# Out:
#             Artist                      Album  Released
# 0  Michael Jackson                   Thriller      1982
# 1            AC/DC              Back in Black      1980
# 2       Pink Floyd  The Dark Side of the Moon      1973

# %%
#df1.append(df2) | Add the rows in df1 to the end of df2 (columns should be identical)
#pd.concat([df1, df2],axis=1) | Add the columns in df1 to the end of df2 (rows should be identical)

# %%
df1 = df.loc[0:2, 'Artist':'Released']
print (df1)
# Out:
#             Artist                      Album  Released
# 0  Michael Jackson                   Thriller      1982
# 1            AC/DC              Back in Black      1980
# 2       Pink Floyd  The Dark Side of the Moon      1973

# %%
df2 = df.loc[4:6, 'Artist':'Released']
print (df2)
# Out:
#       Artist                            Album  Released
# 4  Meat Loaf                  Bat Out of Hell      1977
# 5     Eagles  Their Greatest Hits (1971-1975)      1976
# 6   Bee Gees             Saturday Night Fever      1977

# %%
df1.append(df2)
# Out:
#             Artist                            Album  Released
# 0  Michael Jackson                         Thriller      1982
# 1            AC/DC                    Back in Black      1980
# 2       Pink Floyd        The Dark Side of the Moon      1973
# 4        Meat Loaf                  Bat Out of Hell      1977
# 5           Eagles  Their Greatest Hits (1971-1975)      1976
# 6         Bee Gees             Saturday Night Fever      1977

# %%
type(df1.append(df2))
# Out:
# pandas.core.frame.DataFrame

# %%
pd.concat([df1, df2],axis=1)
# Out:
#             Artist                      Album  Released     Artist  \
# 0  Michael Jackson                   Thriller    1982.0        NaN
# 1            AC/DC              Back in Black    1980.0        NaN
# 2       Pink Floyd  The Dark Side of the Moon    1973.0        NaN
# 4              NaN                        NaN       NaN  Meat Loaf
# 5              NaN                        NaN       NaN     Eagles
# 6              NaN                        NaN       NaN   Bee Gees
#
#                              Album  Released
# 0                              NaN       NaN
# 1                              NaN       NaN
# 2                              NaN       NaN
# 4                  Bat Out of Hell    1977.0
# 5  Their Greatest Hits (1971-1975)    1976.0
# 6             Saturday Night Fever    1977.0

# %%
df1 = df.iloc[0:2, 0:2]
print(df1)
# Out:
#             Artist          Album
# 0  Michael Jackson       Thriller
# 1            AC/DC  Back in Black

# %%
df2 = df.iloc[0:2, 4:6]
print(df2)
# Out:
#             Genre  Music Recording Sales (millions)
# 0  pop, rock, R&B                              46.0
# 1       hard rock                              26.1

# %%
pd.concat([df1, df2], axis=1)
# Out:
#             Artist          Album           Genre  \
# 0  Michael Jackson       Thriller  pop, rock, R&B
# 1            AC/DC  Back in Black       hard rock
#
#    Music Recording Sales (millions)
# 0                              46.0
# 1                              26.1

# %%
dir(pd.core.frame.DataFrame)  #directory for Panda
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_TO_AXIS_NUMBER',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
# ...

# %%
###this solves the problem of having misindexed rows

df1=df.iloc[0:2,3:5]
df2=df.iloc[0:4,3:5]
df3=df1.append(df2)
df3
# Out:
#      Length             Genre
# 0  00:42:19    pop, rock, R&B
# 1  00:42:11         hard rock
# 0  00:42:19    pop, rock, R&B
# 1  00:42:11         hard rock
# 2  00:42:49  progressive rock
# 3  00:57:44    R&B, soul, pop

# %%
 #Creating a new Index solves this problem!
df_new=df3
new_index1=['a','b','c','d','e','f']
new_index2=['0','1','2','3','4','5']
df_new.index=new_index1
df_new.loc['a', 'Length':'Genre']

df_new
# Out:
#      Length             Genre
# a  00:42:19    pop, rock, R&B
# b  00:42:11         hard rock
# c  00:42:19    pop, rock, R&B
# d  00:42:11         hard rock
# e  00:42:49  progressive rock
# f  00:57:44    R&B, soul, pop

# %%
df.count() # total count of elements in each coloumn

# %%
x= df[['Artist']]
x

# %%
df_new.loc['a', 'Length':'Genre']
# Out:
# Length          00:42:19
# Genre     pop, rock, R&B
# Name: a, dtype: object
